# %%
import json
import requests
data = requests.get('http://localhost:50550/select_balances_accaunt_101', data=json.dumps({'limit': 10}))
for row in json.loads(data.text):
	print(row)
# Out:
# ['101', '2022-06-30', 'Кузнецов Максим Сергеевич', '1', '101.34', '11013405000015', '330.28.25.13.110', '5', '100% при вводе в эксплуатацию', '2020-10-28', 'Введено в эксплуатацию', '120', '0.83', '100.00', 'Холодильник ATLANT МХ 5810-62, однокамерный, объем 285 л, без морозильной камеры, белый', '15004.26', '1', '15004.26', '0.00']
# ['101', '2022-06-30', 'Кузнецов Максим Сергеевич', '1', '101.34', '11013405000016', '330.28.25.13.110', '5', '100% при вводе в эксплуатацию', '2020-10-28', 'Введено в эксплуатацию', '120', '0.83', '100.00', 'Холодильник ATLANT МХ 5810-62, однокамерный, объем 285 л, без морозильной камеры, белый', '15004.26', '1', '15004.26', '0.00']
# ...

# %%
# !pip install requests
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.4/164.4 kB 3.7 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 17.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 15.5 MB/s eta 0:00:00
# ...
